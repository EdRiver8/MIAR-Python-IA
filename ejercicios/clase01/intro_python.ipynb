# %%
#Hello World
a = 15
b = "Hola" #fuertemente tipoado ya que no permite a + b = error
# a + b #comentado para evitar el error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 a = 15
#       3 b = "Hola" # fuertemente tipoado ya que no permite a + b = error
# ----> 5 a + b
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
