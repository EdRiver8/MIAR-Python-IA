# %% [markdown]
# 1. Usa el paquete **transformers** para generar una frase a partir de un prompt sencillo

# %% [markdown]
# 2. Carga un tokenizer y cuenta cuántos tokens tiene un texto

# %% [markdown]
# 3. Crea un pipeline que genere dos textos usando dos temperaturas diferentes

# %% [markdown]
# 4. Si tengo  tengo muchos documentos y quiero que el modelo use esa información para responder preguntas, Cómo puedo hacerlo sin volver a entrenarlo?

# %% [markdown]
# 5. Crea un modelo de regresión lineal con scikit-learn para predecir y a partir de x

# %% [markdown]
# 6. ¿Cuál de las siguientes herramientas no forma parte de los servicios cognitivos de azure o azure ai services? Opción única. (5 min)
# a) Azure Language
#
# b) Azure Auto ML
#
# c) Azure Speech
#
# d) Azure OpenAI

# %% [markdown]
# Tu respuesta...

# %% [markdown]
# 7. Se necesita procesar llamadas del centro de atención al cliente, para lo cual se necesita categorizar dichas llamadas en 3 topicos distintos (Denuncias, Compra de productos y Bloqueo de cuenta), además se requiere separar los hablantes en la conversación (Cliente, Ejecutivo) y aplicar análisis sentimental, ¿Cómo resolverías el problema planteado usando Azure Cognitive Services o Azure AI Services?
#
# Describe brevemente como abordarías cada apartado y que herramientas usarías relacionadas a inteligencia artificial.
#
# a) Clasificación de llamadas en tópicos.
#
# b) Separación de hablantes en la conversación.
#
# c) Análisis sentimental de la llamada.
#
# (10 min)

# %% [markdown]
# 8. En el siguiente caso de uso se pide clasificar cada página de un documento pdf, para esto se brindan dos diccionarios:
#
# *   datos_clasificador: contiene un array con la clasificación de cada página del documento.
# *   datos_ocr: contiene el texto extraído de cada página como tablas, clave-valor y campos de texto.
#
# Deberás usar estos datos para generar una tabla en pandas o un nuevo diccionario que contenga un registro por cada documento clasificado, páginas que este contiene, páginas en donde fue localizado en el documento original, además de extraer una keyword por cada documento:
#
# *   Cédula: Fecha de vencimiento
# *   Factura: Importe total
# *   Estado de situación financiera: RUC de la empresa
#
# (30 min)
#
# Resultado esperado:

# %% [markdown]
# Tú respuesta...

# %% [markdown]
# ![ResultadoEsperado.png](data:image/png;base64,...)

# %%
datos_clasificador = [
  {
    "page": 1,
    "predictions": [
      {
        "probability": 0.9910676,
        "tagId": "111",
        "tagName": "Cedula"
      },
      {
        "probability": 0.006186828,
        "tagId": "222",
        "tagName": "Factura"
      },
      {
        "probability": 0.00072793255,
        "tagId": "333",
        "tagName": "EstadoSituacionFinanciera"
      }
    ]
  },{
    "page": 2,
    "predictions": [
      {
        "probability": 0.9310676,
        "tagId": "111",
        "tagName": "Cedula"
      },
      {
        "probability": 0.186828,
        "tagId": "222",
        "tagName": "Factura"
      },
      {
        "probability": 0.072793255,
        "tagId": "333",
        "tagName": "EstadoSituacionFinanciera"
      }
    ]
  },{
    "page": 3,
    "predictions": [
      {
        "probability": 0.01910676,
        "tagId": "111",
        "tagName": "Cedula"
      },
      {
        "probability": 0.96186828,
        "tagId": "222",
        "tagName": "Factura"
      },
      {
        "probability": 0.003255,
        "tagId": "333",
        "tagName": "EstadoSituacionFinanciera"
      }
    ]
  },{
    "page": 4,
    "predictions": [
      {
        "probability": 0.0010676,
        "tagId": "111",
        "tagName": "Cedula"
      },
      {
        "probability": 0.0011682,
        "tagId": "222",
        "tagName": "Factura"
      },
      {
        "probability": 0.82793255,
        "tagId": "333",
        "tagName": "EstadoSituacionFinanciera"
      }
    ]
  },{
    "page": 5,
    "predictions": [
      {
        "probability": 0.000676,
        "tagId": "111",
        "tagName": "Cedula"
      },
      {
        "probability": 0.000682,
        "tagId": "222",
        "tagName": "Factura"
      },
      {
        "probability": 0.807932,
        "tagId": "333",
        "tagName": "EstadoSituacionFinanciera"
      }
    ]
  },{
    "page": 6,
    "predictions": [
      {
        "probability": 0.0000676,
        "tagId": "111",
        "tagName": "Cedula"
      },
      {
        "probability": 0.0001182,
        "tagId": "222",
        "tagName": "Factura"
      },
      {
        "probability": 0.852312,
        "tagId": "333",
        "tagName": "EstadoSituacionFinanciera"
      }
    ]
  }
]

# %%
datos_ocr = {
	"status": "succeeded",
	"createdDateTime": "2024-04-01T04:25:31Z",
	"lastUpdatedDateTime": "2024-04-01T04:25:43Z",
	"analyzeResult": {
		"apiVersion": "2023-07-31",
		"modelId": "prebuilt-document",
		"stringIndexType": "utf16CodeUnit",
		"content": "REPÚBLICA DEL ECUADOR\nCONDICIÓN CHIDADANÍA\nJARAMILLO ALVEAR PATRICIO RAMIRO NACIONALIDAD ECUATORIANA FECHA DE NACIMIENTO 04 JUL 1938 PICHINCHA QUITO SAN BLAS\nHOMERE I. DOCUMENTO 3375.19:239 FECHA DE VENCIMENTO 23 MAR 2030\nNUI:1719429053\nAPELLIDOS Y NOMBRES DEL ADEE JARAMILLO HERNANDEZ PABLO LUCIO\nCÓDIGO DACTILAR\nTIPO DE SANGRE AB+\nALVEAR MENA LUCIA KARINA\nCASADO APELLIDOLY NOUSPES DEL CONTOGA MONTALVO CARRION GISELA PAOLA\nVISUAL 49% DONANCE SI - TEJI005\n200\nQUITO 2021-05-14\n1<ECUM123456 << 9<1719429053 <<< 9507041F2807177ECU<NO<DONANTE9 JARAMILLO<ALVEAR<PATRICIO<RA\nFACTURA\nRojo Polo Paella Inc. Carretera Muelle 38 37531 Ávila, Ávila\nFACTURAR A\nLeda Villareal\nVirgen Blanca 63\n08759 Burgos, Burgos\nENVIAR A\nLeda Villareal\nCercas Bajas 68\n47300 Cádiz, Cádiz\nNº DE FACTURA\nES-001\nFECHA\n29/01/2019\nNº DE PEDIDO\n1730/2019\nFECHA VENCIMIENTO\n29/01/2019\nLOGO\nCANT.\nDESCRIPCIÓN\nPRECIO UNITARIO\nIMPORTE\n1\nTalla pequeña traje de luces en rojo\n100.00\n100.00\n2\nMui grande churrolito\n25.00\n50.00\n3\nEquipaje de Fútbol\n5.00\n15.00\nSubtotal\n165.00\nIVA 21.0%\n34.65\nTOTAL\n199.65 €\nCONDICIONES Y FORMA DE PAGO\nEl pago se realizará en un plazo de 15 días Banco Santander IBAN:
CUENTAS INCOBRABLES Y DETERIORO\n1010207\n0.00\nINVENTARIOS\n10103\n0.00\nINVENTARIOS DE MATERIA PRIMA\n1010301\n0.00\nINVENTARIOS DE PRODUCTOS EN PROCESO\n1010302\n0.00\nINVENTARIOS DE SUMINISTROS O MATERIALES A SER CONSUMIDOS EN EL PROCESO DE PRODUCCIÓN\n1010303\n0.00\nINVENTARIOS DE SUMINISTROS O MATERIALES A SER CONSUMIDOS EN LA PRESTACION DEL SERVICIO\n1010304\n0.00\nINVENTARIOS DE PROD. TERM. Y MERCAD. EN ALMACÉN - PRODUCIDO POR LA COMPAÑÍA\n1010305\n0.00\nINVENTARIOS DE PROD. TERM. Y MERCAD. EN ALMACÉN - COMPRADO A TERCEROS\n1010306\n0.00\nMERCADERÍAS EN TRÁNSITO\n1010307\n0.00\nOBRAS EN CONSTRUCCION\n1010308\n0.00\nOBRAS TERMINADAS\n1010309\n0.00\nMATERIALES O BIENES PARA LA CONSTRUCCION\n1010310\n0.00\nINVENTARIOS REPUESTOS, HERRAMIENTAS Y ACCESORIOS\n1010311\n0,00\nOTROS INVENTARIOS\n1010312\n0.00\n(-) PROVISIÓN POR VALOR NETO DE REALIZACIÓN Y OTRAS PERDIDAS EN INVENTARIO\n1010313\n0.00\nSERVICIOS Y OTROS PAGOS ANTICIPADOS\n10104\n0.00\nSEGUROS PAGADOS POR ANTICIPADO\n1010401\n0.00\nARRIENDOS PAGADOS POR ANTICIPADO\n1010402\n0.00\nANTICIPOS A PROVEEDORES\n1010403\n0,00\nOTROS ANTICIPOS ENTREGADOS\n1010404\n0.00\nACTIVOS POR IMPUESTOS CORRIENTES\n10105\n0.00\nCRÉDITO TRIBUTARIO A FAVOR DE LA EMPRESA (IVA)\n1010501\n0.00\nCRÉDITO TRIBUTARIO A FAVOR DE LA EMPRESA ( I. R.)\n1010502\n0.00\nANTICIPO DE IMPUESTO A LA RENTA\n1010503\n0.00",
		"paragraphs": [
			{
				"boundingRegions": [
					{
						"pageNumber": 1
					}
				],
				"content": "REPÚBLICA DEL"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 1
					}
				],
				"content": "ECUADOR"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 1
					}
				],
				"content": "CONDICIÓN\nJARAMILLO ALVEAR PATRICIO RAMIRO NACIONALIDAD ECUATORIANA FECHA DE NACIMIENTO 04 JUL 1938 PICHINCHA QUITO SAN BLAS"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 1
					}
				],
				"content": "CHIDADANÍA\nHOMERE I. DOCUMENTO 3375.19:239 FECHA DE VENCIMENTO 23 MAR 2030"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 1
					}
				],
				"content": "NUI:1719429053"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 2
					}
				],
				"content": "APELLIDOS Y NOMBRES DEL ADEE JARAMILLO HERNANDEZ PABLO LUCIO"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 2
					}
				],
				"content": "CÓDIGO DACTILAR"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 2
					}
				],
				"content": "TIPO DE SANGRE AB+"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 2
					}
				],
				"content": "ALVEAR MENA LUCIA KARINA"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 2
					}
				],
				"content": "CASADO APELLIDOLY NOUSPES DEL CONTOGA MONTALVO CARRION GISELA PAOLA"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 2
					}
				],
				"content": "VISUAL 49% DONANCE SI - TEJI005"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 2
					}
				],
				"content": "QUITO 2021-05-14"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 2
					}
				],
				"content": "200"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 2
					}
				],
				"content": "1<ECUM123456 << 9<1719429053 <<< 9507041F2807177ECU<NO<DONANTE9 JARAMILLO<ALVEAR<PATRICIO<RA"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "FACTURA"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "Rojo Polo Paella Inc. Carretera Muelle 38 37531 Ávila, Ávila"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "FACTURAR A"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3,
					}
				],
				"content": "Leda Villareal"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "Virgen Blanca 63"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "08759 Burgos, Burgos"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "ENVIAR A"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "Leda Villareal"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "Cercas Bajas 68"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "47300 Cádiz, Cádiz"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "Nº DE FACTURA"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "ES-001"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "FECHA"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "29/01/2019"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "Nº DE PEDIDO"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "1730/2019"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "FECHA VENCIMIENTO"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "29/01/2019"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "LOGO"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "CANT."
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "DESCRIPCIÓN"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "PRECIO UNITARIO"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "IMPORTE"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "1"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "Talla pequeña traje de luces en rojo"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "100.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "100.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "2"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "Mui grande churrolito"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "25.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "50.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "3"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "Equipaje de Fútbol"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "5.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "15.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "Subtotal"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "165.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "IVA 21.0%"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "34.65"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "TOTAL"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "199.65 €"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "CONDICIONES Y FORMA DE PAGO"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "El pago se realizará en un plazo de 15 días Banco Santander IBAN: ES12 3456 7891 SWIFT/BIC: ABCDESM1XXX"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 3
					}
				],
				"content": "Gracias"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "SUPERINTENDENCIA DE COMPAÑÍAS, VALORES Y SEGUROS"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "RAZÓN SOCIAL"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "ABEQUIMICA SA"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "DIRECCIÓN"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "MIRAFLORES CALLE 4TA Y AVDA CENTRAL No. 211 BARRIO: MIRAFLORES"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "EXPEDIENTE"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "9780"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "RUC"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0990381038001"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "AÑO"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "2022"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "FORMULARIO"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "SCV.NIIF.9780.2022.1"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "FECHA DE LA JUNTA QUE APROBÓ LOS ESTADOS FINANCIEROS (DD/MM/AAA)"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "Apr 12, 20"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "ESTADO DE SITUACIÓN FINANCIERA"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "CUENTA"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "CÓDIGO"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "VALOR (En USD$)"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "ACTIVO"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "1"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "167854.63"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "ACTIVO CORRIENTE"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "101"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "167854.63"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "EFECTIVO Y EQUIVALENTES DE EFECTIVO"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "10101"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "CAJA"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "1010101"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "INSTITUCIONES FINANCIERAS PÚBLICAS"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "1010102"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "INSTITUCIONES FINANCIERAS PRIVADAS"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "1010103"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "ACTIVOS FINANCIEROS"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "10102"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "ACTIVOS FINANCIEROS A VALOR RAZONABLE CON CAMBIOS EN RESULTADOS"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "1010201"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "RENTA VARIABLE"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "101020101"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "ACCIONES Y PARTICIPACIONES"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "10102010101"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "CUOTAS DE FONDOS COLECTIVOS"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "10102010102"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "VALORES DE TITULARIZACIÓN DE PARTICIPACIÓN"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "10102010103"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "UNIDADES DE PARTICIPACIÓN"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "10102010104"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "INVERSIONES EN EL EXTERIOR"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "10102010105"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "OTROS"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "10102010106"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "RENTA FIJA"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "101020102"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "AVALES"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "10102010201"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "BONOS DEL ESTADO"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "10102010202"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "BONOS DE PRENDA"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "10102010203"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "CÉDULAS HIPOTECARIAS"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "10102010204"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0,00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "CERTIFICADOS FINANCIEROS"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "10102010205"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "CERTIFICADOS DE INVERSIÓN"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "10102010206"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "CERTIFICADOS DE TESORERÍA"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "10102010207"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "CERTIFICADOS DE DEPÓSITO"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "10102010208"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "CUPONES"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "10102010209"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "DEPÓSITOS A PLAZO"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "10102010210"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "LETRAS DE CAMBIO"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "10102010211"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "NOTAS DE CRÉDITO"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "10102010212"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "OBLIGACIONES"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "10102010213"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "FACTURAS COMERCIALES NEGOCIABLES"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "10102010214"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "OVERNIGHTS"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "10102010215"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "OBLIGACIONES CONVERTIBLES EN ACCIONES"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 4
					}
				],
				"content": "10102

			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "(-) PROVISIÓN POR VALOR NETO DE REALIZACIÓN Y OTRAS PERDIDAS EN INVENTARIO"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "1010313"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "SERVICIOS Y OTROS PAGOS ANTICIPADOS"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "10104"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "SEGUROS PAGADOS POR ANTICIPADO"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "1010401"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "ARRIENDOS PAGADOS POR ANTICIPADO"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "1010402"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "ANTICIPOS A PROVEEDORES"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "1010403"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "0,00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "OTROS ANTICIPOS ENTREGADOS"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "1010404"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "ACTIVOS POR IMPUESTOS CORRIENTES"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "10105"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "CRÉDITO TRIBUTARIO A FAVOR DE LA EMPRESA (IVA)"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "1010501"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "CRÉDITO TRIBUTARIO A FAVOR DE LA EMPRESA ( I. R.)"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "1010502"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "0.00"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "ANTICIPO DE IMPUESTO A LA RENTA"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "1010503"
			},
			{
				"boundingRegions": [
					{
						"pageNumber": 6
					}
				],
				"content": "0.00"
			}
		],
		"keyValuePairs": [
			{
				"key": {
					"content": "DE NACIMIENTO",
					"boundingRegions": [
						{
							"pageNumber": 1
						}
					]
				},
				"value": {
					"content": "04 JUL 1938\nSAN BLAS",
					"boundingRegions": [
						{
							"pageNumber": 1
						}
					]
				},
				"confidence": 0
			},
			{
				"key": {
					"content": "DE VENCIMENTO",
					"boundingRegions": [
						{
							"pageNumber": 1
						}
					]
				},
				"value": {
					"content": "23 MAR 2030",
					"boundingRegions": [
						{
							"pageNumber": 1
						}
					]
				},
				"confidence": 0.109
			},
			{
				"key": {
					"content": "APELLIDOS Y NOMBRES DEL ADEE",
					"boundingRegions": [
						{
							"pageNumber": 2
						}
					]
				},
				"value": {
					"content": "JARAMILLO HERNANDEZ PABLO LUCIO\nKARINA",
					"boundingRegions": [
						{
							"pageNumber": 2
						}
					]
				},
				"confidence": 0
			},
			{
				"key": {
					"content": "FACTURAR A",
					"boundingRegions": [
						{
							"pageNumber": 3
						}
					]
				},
				"value": {
					"content": "Leda Villareal\nVirgen Blanca 63\n08759 Burgos, Burgos",
					"boundingRegions": [
						{
							"pageNumber": 3
						}
					]
				},
				"confidence": 0.846
			},
			{
				"key": {
					"content": "ENVIAR A",
					"boundingRegions": [
						{
							"pageNumber": 3
						}
					]
				},
				"value": {
					"content": "Leda Villareal\nCercas Bajas 68\n47300 Cádiz, Cádiz",
					"boundingRegions": [
						{
							"pageNumber": 3
						}
					]
				},
				"confidence": 0.847
			},
			{
				"key": {
					"content": "Nº DE FACTURA",
					"boundingRegions": [
						{
							"pageNumber": 3
						}
					]
				},
				"value": {
					"content": "ES-001",
					"boundingRegions": [
						{
							"pageNumber": 3
						}
					]
				},
				"confidence": 0.891
			},
			{
				"key": {
					"content": "FECHA",
					"boundingRegions": [
						{
							"pageNumber": 3
						}
					]
				},
				"value": {
					"content": "29/01/2019",
					"boundingRegions": [
						{
							"pageNumber": 3
						}
					]
				},
				"confidence": 0.923
			},
			{
				"key": {
					"content": "Nº DE PEDIDO",
					"boundingRegions": [
						{
							"pageNumber": 3
						}
					]
				},
				"value": {
					"content": "1730/2019",
					"boundingRegions": [
						{
							"pageNumber": 3
						}
					]
				},
				"confidence": 0.889
			},
			{
				"key": {
					"content": "FECHA VENCIMIENTO",
					"boundingRegions": [
						{
							"pageNumber": 3
						}
					]
				},
				"value": {
					"content": "29/01/2019",
					"boundingRegions": [
						{
							"pageNumber": 3
						}
					]
				},
				"confidence": 0.907
			},
			{
				"key": {
					"content": "Subtotal",
					"boundingRegions": [
						{
							"pageNumber": 3
						}
					]
				},
				"value": {
					"content": "165.00",
					"boundingRegions": [
						{
							"pageNumber": 3
						}
					]
				},
				"confidence": 0.923
			},
			{
				"key": {
					"content": "IVA 21.0%",
					"boundingRegions": [
						{
							"pageNumber": 3
						}
					]
				},
				"value": {
					"content": "34.65",
					"boundingRegions": [
						{
							"pageNumber": 3
						}
					]
				},
				"confidence": 0.907
			},
			{
				"key": {
					"content": "TOTAL",
					"boundingRegions": [
						{
							"pageNumber": 3
						}
					]
				},
				"value": {
					"content": "199.65 €",
					"boundingRegions": [
						{
							"pageNumber": 3
						}
					]
				},
				"confidence": 0.683
			},
			{
				"key": {
					"content": "IBAN:",
					"boundingRegions": [
						{
							"pageNumber": 3
						}
					]
				},
				"value": {
					"content": "ES12 3456 7891",
					"boundingRegions": [
						{
							"pageNumber": 3
						}
					]
				},
				"confidence": 0.885
			},
			{
				"key": {
					"content": "SWIFT/BIC:",
					"boundingRegions": [
						{
							"pageNumber": 3
						}
					]
				},
				"value": {
					"content": "ABCDESM1XXX",
					"boundingRegions": [
						{
							"pageNumber": 3
						}
					]
				},
				"confidence": 0.922
			},
			{
				"key": {
					"content": "BARRIO:",
					"boundingRegions": [
						{
							"pageNumber": 4
						}
					]
				},
				"value": {
					"content": "MIRAFLORES",
					"boundingRegions": [
						{
							"pageNumber": 4
						}
					]
				},
				"confidence": 0.884
			}
		]
	}
}
